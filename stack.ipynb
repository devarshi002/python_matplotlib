# %% [markdown]
# # stack plot

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
a1 = [2,5,4,6,9]
a2 = [2,5,3,4,6]
a3 = [1,2,4,3,5]

l =["a1", "a2", "a3"]
plt.stackplot(x, a1, a2, a3, labels=l)
plt.legend(loc=2)
plt.title("python")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
