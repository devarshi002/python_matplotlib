# %% [markdown]
# # histogram plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [50 12 17 15 38 31 37 40 25 30 48 41 37 48 47 40 50 17 59 56 38 47 58 44
#  56 13 38 46 31 35 17 37 56 44 42 37 15 46 24 56 37 37 38 19 55 55 32 59
#  38 22]

# %%
no=[50, 12, 17, 15, 38, 31, 37, 40, 25, 30, 48, 41, 37, 48, 47, 40, 50, 17, 59, 56, 38, 47, 58, 44,
 56, 13, 38, 46, 31, 35, 17, 37, 56, 44, 42, 37, 15, 46, 24, 56, 37, 37, 38, 19, 55, 55, 32, 59,
 38, 22]
l=[10,20,30,40,50,60]
plt.hist(no, color="g", edgecolor="black", bins=l, label="python")
plt.legend()
plt.title("wscube")
plt.xlabel("python")
plt.ylabel("no.")
plt.show()
