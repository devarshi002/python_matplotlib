# %% [markdown]
# # boxplot

# %%
import matplotlib.pyplot as plt

x = [ 10, 20, 30, 40, 50, 60, 70, 120]
plt.boxplot(x, notch=False, vert= True, labels=["python"], patch_artist=False, boxprops=dict(color="g"), capprops=dict(color="r"), whiskerprops=dict(color="b"))

plt.show()
